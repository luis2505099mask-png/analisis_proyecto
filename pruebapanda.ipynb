# %% [markdown]
# # Primera ocasion usando pandas

# %%
import pandas as pd

# %%
data = {
    'manzanas' : [3,2,0,1],
    'naranjas' : [0,3,1,2],
    'kiwis' :    [1,1,5,2]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    manzanas  naranjas  kiwis
# 0         3         0      1
# 1         2         3      1
# 2         0         1      5
# 3         1         2      2

# %%
manzanas = df['manzanas']
manzanas
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# Name: manzanas, dtype: int64

# %%
df.naranjas
# Out:
# 0    0
# 1    3
# 2    1
# 3    2
# Name: naranjas, dtype: int64

# %%
list(df.naranjas)
# Out:
# [0, 3, 1, 2]

# %%
df.read_csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.read_csv
#
# File c:\Users\rinzl\analisis_proyecto\entorno\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.metrics import mean_absolute_error
#       2 from sklearn.tree import DecisionTreeRegressor
#
# ModuleNotFoundError: No module named 'sklearn'
